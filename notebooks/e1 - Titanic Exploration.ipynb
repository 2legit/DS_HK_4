# %% [markdown]
# Titanic: Machine Learning from Disaster - Part 1
# ================================================

# %% [markdown]
# Sign up to [Kaggle]
# [Kaggle]: https://www.kaggle.com/account/register
# Join the [Titanic competition], download the train set and test set.
# [Titanic competition]: https://www.kaggle.com/c/titanic-gettingStarted

# %% [markdown]
# **Remember the data science work flow? **
#
# Problem definition:
# Our objective is to predict what type of passengers would survive or not. (Take a look at the Evaluation page for the Kaggle competition.)
#
# > For each passenger in the test set, you must predict whether or not they survived the sinking ( 0 for deceased, 1 for survived ).  Your score is the percentage of passengers you correctly predict.
#
# Let's load the data and take a look.

# %% [markdown]
# **WHAT ARE OUR HYPOTHESES?**
# What type of people have a better chance of survival?
# A. Men vs women
# B. Adult vs children
# C. Rich vs poor
# D. (What else??)

# %%
# Import libraries

from __future__ import division
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import re

# %%
#load data in pandas dataframe
DATAFOLDER = "../Documents/"
train = pd.read_csv(DATAFOLDER + "titanic_train.csv")

# %%
list(train.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
# let's make sure we know what the headers mean

# VARIABLE DESCRIPTIONS:  
# survival        Survival  
#                 (0 = No; 1 = Yes)  
# pclass          Passenger Class  
#                 (1 = 1st; 2 = 2nd; 3 = 3rd)  
# name            Name  
# sex             Sex  
# age             Age  
# sibsp           Number of Siblings/Spouses Aboard  
# parch           Number of Parents/Children Aboard  
# ticket          Ticket Number  
# fare            Passenger Fare  
# cabin           Cabin  
# embarked        Port of Embarkation  
#                (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
train.describe()
# this only show the numerical data
# Age column has missing data
# Fare is weird - there are cases of very high fares
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male  NaN      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %% [markdown]
# **What to do with missing data?**
#
# Method 1: Just drop the rows where age is not available.
# (Why would that cause a problem?)
#
# Method 2: Fillna with mean

# %%
train['Age2'] = train['Age'].fillna(train['Age'].mean())
train['Age2'].head()
# Out:
# 0    22
# 1    38
# 2    26
# 3    35
# 4    35
# Name: Age2, dtype: float64

# %% [markdown]
# **Many methods**: Use the family data to estimate missing age. See a Kaggler's [attempt here] and the [forum discussion] here.
# [attempt here]: https://github.com/matthagy/titanic-families/blob/master/findfamilies.py
# [forum discussion]: https://www.kaggle.com/c/titanic-gettingStarted/forums/t/2899/any-interest-in-family-trees

# %%
# What should be done with columns such as train['ticket'] and train['cabin']?
train2 = train.drop(['Ticket','Cabin'], axis=1)  
train2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch     Fare Embarked  Age2
# 0      0   7.2500        S    22
# 1      0  71.2833        C    38
# 2      0   7.9250        S    26
# 3      0  53.1000        S    35
# 4      0   8.0500        S    35

# %%
# Explore survival rates by plotting

fig = plt.figure(figsize=(18,6), dpi=1600) 
ax1 = plt.subplot2grid((1,3),(0,0))
ax1.set_xlim(-1, 2)
plt.title("Distribution of Survival, (1 = Survived)") 
train['Survived'].value_counts().plot(kind='bar')

# plt.subplot2grid((1,3),(0,1))
# plt.scatter(train['Survived'], train['Age2'])
# plt.ylabel("Age")
# plt.grid(b=True, which='major', axis='y')  
# plt.title("Survial by Age,  (1 = Survived)")

# ax3 = plt.subplot2grid((1,3),(0,2))
# train['Pclass'].value_counts().plot(kind="barh")
# ax3.set_ylim(-1, len(train['Pclass'].value_counts()))
# plt.title("Class Distribution")

# %%
# Distribution of embarking location
# train['Embarked'].value_counts().plot(kind='bar')
# plt.title("Passengers per embarking location")

# %%
#What to do with the text columns
train['Sex'].head(5)
# Out:
# 0      male
# 1    female
# 2    female
# 3    female
# 4      male
# Name: Sex, dtype: object

# %%
#Vectorize gender into 0 or 1
train['Gender'] = train['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
train['Gender'].head(10)
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# 5    1
# 6    1
# 7    1
# 8    0
# 9    0
# Name: Gender, dtype: int64
